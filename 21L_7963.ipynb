# %%
#QUESTION-1
def check_input(test):
    rows = len(test)
    cols = len(test[0])
    for r in range(rows):
        for c in range(cols):
            if (type(test[r][c]) == str):
                return False
            elif c + 1 < cols:
             if(test[r][c] == test[r][c+1]):
                return False
    for c in range(cols):
        for r in range(rows):
            if r+1 < rows:
             if (test[r][c] == test[r+1][c]):
                return False
    return True

test1 = [[1, 2, 3],[2, 3, 1],[3, 1, 2]]
test2 = [[1, 2, 3, 4],[2, 3, 1, 3],[3, 1, 2, 3],[4, 4, 4, 4]]
test3 = [['a', 'b', 'c'],['b', 'c', 'a'],['c', 'a', 'b']]

print(check_input(test1))
print(check_input(test2))
print(check_input(test3))
# Out:
# True
# False
# False

# %%
#TO-IMPORT-DATA
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0dbca4ab-5c1f-4a3a-a2e3-5b188c0ae738" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0dbca4ab-5c1f-4a3a-a2e3-5b188c0ae738">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#QUESTION-2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import io
#PART-A
print("\n PART-A")
database = pd.read_csv(io.BytesIO(uploaded["StudentMarkSheet.csv"]))
database.info()
#PART-B
print("\n PART-B")
print("Number of rows: ", database.shape[0])
length = database.shape[0]
database = database.dropna()
nulls = length - database.shape[0]
print("Number of Rows with Null-Entries: ", nulls)
print("Number of Rows after Null-Entries Removed: ", database.shape[0])
#PART-C
print("\n PART-C")
student=database.loc[database["Student name"]=="James Walker",("Student name","Exam name","Marks")]
print(student)
# Out:
#  PART-A
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student name  200 non-null    object
#  1   Exam name     199 non-null    object
#  2   Exam date     200 non-null    object
#  3   Marks         197 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 6.4+ KB
#
#  PART-B
# Number of rows:  200
# Number of Rows with Null-Entries:  4
# Number of Rows after Null-Entries Removed:  196
#
#  PART-C
#      Student name    Exam name  Marks
# 0    James Walker      Biology   31.0
# 42   James Walker    Chemistry   61.0
# 71   James Walker  Mathematics   23.0
# 150  James Walker      Physics  100.0
# 180  James Walker    Sociology   73.0

# %%
#QUESTION-3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import io
#PART-A
print("\n PART-A")

Biology = database.loc[database["Exam name"] == "Biology", "Marks"]
TotalBiology = Biology.count()
SumBiology = Biology.sum()
AverageBiology = SumBiology / TotalBiology
print("Average Marks of students in Biology: ",AverageBiology)

Chemistry = database.loc[database["Exam name"] == "Chemistry", "Marks"]
TotalChemistry = Chemistry.count()
SumChemistry = Chemistry.sum()
AverageChemistry = SumChemistry / TotalChemistry
print("Average Marks of students in Chemistry: ",AverageChemistry)

Mathematics = database.loc[database["Exam name"] == "Mathematics", "Marks"]
TotalMathematics = Mathematics.count()
SumMathematics = Mathematics.sum()
AverageMathematics = SumMathematics / TotalMathematics
print("Average Marks of students in Maths: ",AverageMathematics) #output showing nan (not a number) because of empty entries!

Philosophy = database.loc[database["Exam name"] == "Philosophy", "Marks"]
TotalPhilosophy = Philosophy.count()
SumPhilosophy = Philosophy.sum()
AveragePhilosophy = SumPhilosophy / TotalPhilosophy
print("Average Marks of students in Philosophy: ",AveragePhilosophy)

Physics = database.loc[database["Exam name"] == "Physics", "Marks"]
TotalPhysics = Physics.count()
SumPhysics = Physics.sum()
AveragePhysics = SumPhysics / TotalPhysics
print("Average Marks of students in Physics: ",AveragePhysics)

Sociology = database.loc[database["Exam name"] == "Sociology", "Marks"]
TotalSociology = Sociology.count()
SumSociology = Sociology.sum()
AverageSociology = SumSociology / TotalSociology
print("Average Marks of students in Sociology: ",AverageSociology)

#PART-B
print("\n PART-B")

df = pd.DataFrame({'Subjects':['Biology', 'Chemistry', 'Mathematics','Philosophy','Physics','Sociology'], 'Average Marks':[AverageBiology, AverageChemistry, AverageMathematics,AveragePhilosophy,AveragePhysics,AverageSociology]})
df.plot.bar(rot=0, color='blue', width=0.5)

plt.title("Averages of Each Subject.\nSubjects at x-axis. Marks at y-axis")
plt.show()
# Out:
#  PART-A
# Average Marks of students in Biology:  47.89473684210526
# Average Marks of students in Chemistry:  50.57692307692308
# Average Marks of students in Maths:  48.97222222222222
# Average Marks of students in Philosophy:  47.270270270270274
# Average Marks of students in Physics:  51.76190476190476
# Average Marks of students in Sociology:  56.026315789473685
#
#  PART-B

# %%
#QUESTION-4
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import io

#PART-A
print("\n PART-A \n Null entries removed!")
df = pd.read_csv(io.BytesIO(uploaded["CatData.csv"]))
df = df.dropna()

#PART-B
print("\n PART-B")
df = df[["Tail Length (cm)", "Mass (kg)"]]
num = int(len(df)*0.8)
train = df[:num]
test = df[num:]
print("Data: ", len(df))
print("Train:\n", train)
print("Test:\n", test)

#PART-C
print("\n PART-C")
regression = linear_model.LinearRegression()
train_x = np.array(train[["Tail Length (cm)"]])
train_y = np.array(train[["Mass (kg)"]])
regression.fit(train_x, train_y)
coefficients = regression.coef_
intercept = regression.intercept_
print("Slope after using regression model: ", coefficients[0])
print("Intercept after using regression model: ", intercept)

#PART-D
print("\n PART-D")
plt.scatter(df["Tail Length (cm)"], df["Mass (kg)"])
plt.plot(train_x, coefficients * train_x+intercept, color='black')
plt.title("Linear Regression")
plt.xlabel("Tail Length (cm)")
plt.ylabel("Mass (kg)")
plt.show()
# Out:
#  PART-A
#  Null entries removed!
#
#  PART-B
# Data:  342
# Train:
#       Tail Length (cm)  Mass (kg)
# 0                18.1      3.750
# 1                18.6      3.800
# 2                19.5      3.250
# 3                19.3      3.450
# 4                19.0      3.650
# ..                ...        ...
# 268              22.2      6.000
# 269              21.4      4.925
# 270              21.5      4.850
# 271              22.2      5.750
# 272              21.2      5.200
#
# [273 rows x 2 columns]
# Test:
#       Tail Length (cm)  Mass (kg)
# 273              21.3      5.400
# 274              19.2      3.500
# 275              19.6      3.900
# 276              19.3      3.650
# 277              18.8      3.525
# ..                ...        ...
# 337              20.7      4.000
# 338              20.2      3.400
# 339              19.3      3.775
# 340              21.0      4.100
# 341              19.8      3.775
#
# [69 rows x 2 columns]
#
#  PART-C
# ...
